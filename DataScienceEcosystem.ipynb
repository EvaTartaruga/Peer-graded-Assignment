# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries in data science
# - Tabulate three development environment open source tools used in data science
# - Use arithmetic expressions with explanatory comments
# - Use different headings, list (ordered and unordered), tables and emphasis in the Markdown Cells
# - Share this Jupyter Notebook through GitHub

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Others: Scala, Java, C++, and Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas (Pyhton library)
# 2. NumPy (Pyhton library)
# 3. Scikit-learn (ML Pyhton library)
# 4. TensorFlow (DL Pyhton library)
# 5. Vegas (Scala library)

# %% [markdown]
# | Data Science Tools |
# | ------------- |
# | Jupyter Notebooks |
# | RStudio |
# | Apache Spark |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
#This a simple arithmetic expression to mutiply then add integers.

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.
# 1h= 60 min
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Eva Villar Álvarez
